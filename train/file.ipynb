# %%
import pandas as pd
df=pd.read_csv('TrainFD_LPMCS_512.csv')

# %%
df
# Out:
#           ID                                           Judgment  \
# 0    id_1498  and\nW.M.P.(MD)No.21615 of 2022\nS.Lawrence Vi...
# 1      id_16  This file relates to reconsideration of the pr...
# 2    id_1106  1PA./RG/Misc./2021 Date-24.06.202L\nConsiderin...
# 3     id_539  IN THE HIGH COURT OF MADHYA PRADESHAT JABALPUR...
# 4    id_1205  Crl. A. No.1200/2023\nCriminal Appeal No.1200 ...
# ..       ...                                                ...
# 955   id_797  Haji Abdul Gani Khan & Anr. …Petitioners\nv.\n...
# 956   id_863  Khalil Abbas Fakir ….. Applicant\nTabbasum Kha...
# 957   id_911  (Criminal Revisional Jurisdiction)\nAppellate ...
# 958   id_527  1 CC.No.30751/2021\nDated this the 18th day of...
# 959   id_907  S.B. Criminal Writ Petition No. 565/2022\nShas...
#
#                                                Summary
# 0    Designation of a lawyer as a Senior Advocate i...
# 1    The Union Law Minister told the Supreme Court ...
# 2    The Rajasthan High Court will start regular he...
# 3    The Madhya Pradesh High Court recently quashed...
# 4    While society should be protected from drug-re...
# ..                                                 ...
# 955  The Supreme Court on Monday dismissed the peti...
# 956  The Bombay High Court recently held that a div...
# 957  The Calcutta High Court recently quashed a che...
# 958  An Special Court in Bengaluru recently convict...
# 959  Surveillance without procedural safeguards wou...
#
# [960 rows x 3 columns]

# %%
import json
def load_jsonl(path):
    records = []
    with open(path, "r", encoding="utf-8") as f:
        for line in f:
            records.append(json.loads(line))
    return pd.DataFrame(records)

# %%
original_df = load_jsonl("train_split.jsonl")
original_df
# Out:
#           ID                                           Judgment  \
# 0    id_1498  and\nW.M.P.(MD)No.21615 of 2022\nS.Lawrence Vi...
# 1      id_16  This file relates to reconsideration of the pr...
# 2    id_1106  1PA./RG/Misc./2021 Date-24.06.202L\nConsiderin...
# 3     id_539  IN THE HIGH COURT OF MADHYA PRADESHAT JABALPUR...
# 4    id_1205  Crl. A. No.1200/2023\nCriminal Appeal No.1200 ...
# ..       ...                                                ...
# 955   id_797  Haji Abdul Gani Khan & Anr. …Petitioners\nv.\n...
# 956   id_863  Khalil Abbas Fakir ….. Applicant\nTabbasum Kha...
# 957   id_911  (Criminal Revisional Jurisdiction)\nAppellate ...
# 958   id_527  1 CC.No.30751/2021\nDated this the 18th day of...
# 959   id_907  S.B. Criminal Writ Petition No. 565/2022\nShas...
#
#                                                Summary
# 0    Designation of a lawyer as a Senior Advocate i...
# 1    The Union Law Minister told the Supreme Court ...
# 2    The Rajasthan High Court will start regular he...
# 3    The Madhya Pradesh High Court recently quashed...
# 4    While society should be protected from drug-re...
# ..                                                 ...
# 955  The Supreme Court on Monday dismissed the peti...
# 956  The Bombay High Court recently held that a div...
# 957  The Calcutta High Court recently quashed a che...
# 958  An Special Court in Bengaluru recently convict...
# 959  Surveillance without procedural safeguards wou...
#
# [960 rows x 3 columns]

# %%
tokenize.sentencepiece_tokenizer
